# %% [markdown]
# # Arizona FARMS Agrivoltaic Test Site Irradiance Modeling
#
# Author: Kai Lepley
# Origin: November 17, 2023
# Updated: November 17, 2023
#
# Here, I will be modeling the University of Arizona FARMS field site, managed by AES near Casa Grande, Arizona. The site is a 121 MW PV site composed of single-axis tracking panels with an 18-foot row spacing.
#
# Specs:<br>
# Row-spacing: 20' = 6096mm<br>
# Panel: First Solar Series 6 435W (thin-film monofacial)<br>
# Panel length: 2009mm<br>
# Panel width: 1232mm<br>
# Panel orientation: 1P<br>
# Tracking: single-axis east-west<br>
# Grade to top of pile: 4' 11" = 1498.6mm<br>
# Top of pile to torque tube: 6" = 152.4mm<br>
# Module to grade: 30" = 762mm<br>
# Max tracker tiler: 52°<br>
# GCR: panel length / row-spacing = 2009mm / 6096mm = 0.33<br>
#
# Assuming 1-meter panel height. This should be updated with more accuract specifications later.
#
# Kai's NSRDB API Key: BY01WmafAijSce07CkJFJpsyBSzuEEJHmHSrlNkU

# %%
NREL_API_KEY = 'BY01WmafAijSce07CkJFJpsyBSzuEEJHmHSrlNkU'  # <-- please set your NREL API key here
# note you must use "quotes" around your key as it is a string.

if NREL_API_KEY is None:
       NREL_API_KEY = 'DEMO_KEY'  # OK for this demo, but better to get your own key

# %%
import pvlib

metdata, metadata = pvlib.iotools.get_psm3(
    latitude=32.852182, longitude=-111.554986,
    api_key=NREL_API_KEY,
    email='kai.lepley@nrel.gov',
    names='tmy', map_variables=True)
metadata
# Out:
# {'Source': 'NSRDB',
#  'Location ID': '73012',
#  'City': '-',
#  'State': '-',
#  'Country': '-',
#  'Time Zone': -7,
#  'Local Time Zone': -7,
#  'Dew Point Units': 'c',
#  'DHI Units': 'w/m2',
#  'DNI Units': 'w/m2',
#  'GHI Units': 'w/m2',
#  'Temperature Units': 'c',
#  'Pressure Units': 'mbar',
#  'Wind Direction Units': 'Degrees',
#  'Wind Speed Units': 'm/s',
#  'Surface Albedo Units': 'N/A',
#  'Version': '3.2.0',
#  'latitude': 32.85,
#  'longitude': -111.54,
#  'altitude': 442}

# %%
from bifacial_radiance import *
import numpy as np

#bifacial_radiance.__version__

# %%
import os
from pathlib import Path

testfolder = str(Path().resolve().parent.parent / 'TEMP' /  'FARMS_Arizona')

if not os.path.exists(testfolder):
    os.makedirs(testfolder)
    
print ("Your simulation will be stored in %s" % testfolder)
# Out:
# Your simulation will be stored in /Users/klepley/Documents/GitHub/InSPIRE/TEMP/FARMS_Arizona

# %%
# Create a RadianceObj 'object' named bifacial_example. no whitespace allowed
radObj = RadianceObj('FARMS_Arizona', path = str(testfolder))

albedo = 0.25
radObj.setGround(albedo)
# Out:
# path = /Users/klepley/Documents/GitHub/InSPIRE/TEMP/FARMS_Arizona
# Loading albedo, 1 value(s), 0.250 avg
# 1 nonzero albedo values.

# %%
# Some of the names changed internally. While bifacial_radiance updates their expected names, we are renaming the values here
metadata['timezone'] = metadata['Time Zone']
metadata['county'] = 'Pinal'
metadata['elevation'] = metadata['altitude']
metadata['state'] = metadata['State']
metadata['country'] = metadata['Country']
metdata['Albedo'] = metdata['albedo']

# %%
#starttime can be 'MM_DD', or 'MM_DD_HH'
#metData = radObj.NSRDBWeatherData(metadata, metdata, starttime='03_10_21', endtime='11_21_21',coerce_year=2021)

# Above was working, but suddenly began giving "no attribute NSRDBWeatherData", so trying EPW
# Pull in meteorological data using pyEPW for any global lat/lon
epwfile = radObj.getEPW(lat = 32.852182, lon = -111.554986)  # Coordinates of array
# Read in the weather data pulled in above.
metdata = radObj.readWeatherFile(weatherFile = epwfile)
# Out:
# Getting weather file: USA_AZ_Casa.Grande.AWOS.722748_TMY3.epw
#  ... OK!
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2021
# Saving file EPWs/metdata_temp.csv, # points: 8760
# Calculating Sun position for Metdata that is right-labeled  with a delta of -30 mins. i.e. 12 is 11:30 sunpos

# %%
metdata.datetime  # printing the contents of metData to see how many times got loaded.
# Out:
# [Timestamp('2021-01-01 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-01 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-01 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-01 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-01 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-01 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-01 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-01 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-01 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-02 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-02 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-02 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-02 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-02 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-02 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-02 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-02 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-02 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-03 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-03 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-03 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-03 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-03 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-03 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-03 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-03 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-03 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-03 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-04 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-04 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-04 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-04 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-04 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-04 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-04 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-04 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-04 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-04 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-05 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-05 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-05 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-05 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-05 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-05 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-05 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-05 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-05 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-05 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-06 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-06 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-06 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-06 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-06 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-06 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-06 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-06 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-06 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-06 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-07 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-07 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-07 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-07 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-07 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-07 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-07 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-07 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-07 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-07 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-08 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-08 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-08 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-08 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-08 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-08 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-08 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-08 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-08 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-08 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-09 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-09 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-09 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-09 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-09 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-09 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-09 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-09 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-09 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-09 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-10 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-10 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-10 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-10 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-10 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-10 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-10 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-10 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-10 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-10 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-11 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-11 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-11 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-11 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-11 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-11 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-11 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-11 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-11 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-11 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-12 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-12 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-12 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-12 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-12 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-12 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-12 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-12 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-12 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-12 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-13 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-13 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-13 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-13 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-13 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-13 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-13 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-13 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-13 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-13 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-14 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-14 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-14 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-14 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-14 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-14 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-14 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-14 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-14 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-14 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-15 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-15 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-15 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-15 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-15 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-15 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-15 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-15 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-15 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-15 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-16 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-16 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-16 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-16 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-16 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-16 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-16 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-16 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-16 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-16 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-17 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-17 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-17 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-17 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-17 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-17 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-17 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-17 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-17 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-17 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-18 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-18 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-18 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-18 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-18 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-18 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-18 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-18 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-18 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-18 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-19 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-19 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-19 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-19 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-19 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-19 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-19 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-19 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-19 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-19 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-20 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-20 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-20 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-20 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-20 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-20 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-20 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-20 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-20 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-20 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-21 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-21 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-21 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-21 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-21 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-21 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-21 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-21 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-21 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-21 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-22 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-22 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-22 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-22 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-22 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-22 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-22 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-22 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-22 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-22 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-23 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-23 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-23 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-23 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-23 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-23 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-23 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-23 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-23 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-23 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-24 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-24 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-24 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-24 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-24 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-24 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-24 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-24 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-24 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-24 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-24 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-25 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-25 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-25 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-25 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-25 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-25 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-25 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-25 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-25 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-25 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-25 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-26 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-26 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-26 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-26 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-26 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-26 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-26 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-26 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-26 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-26 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-26 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-27 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-27 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-27 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-27 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-27 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-27 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-27 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-27 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-27 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-27 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-27 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-28 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-28 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-28 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-28 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-28 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-28 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-28 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-28 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-28 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-28 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-28 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-29 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-29 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-29 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-29 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-29 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-29 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-29 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-29 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-29 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-29 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-29 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-30 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-30 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-30 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-30 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-30 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-30 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-30 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-30 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-30 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-30 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-30 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-31 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-31 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-31 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-31 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-31 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-31 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-31 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-31 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-31 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-31 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-01-31 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-01 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-01 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-01 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-01 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-01 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-01 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-01 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-01 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-01 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-01 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-01 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-02 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-02 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-02 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-02 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-02 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-02 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-02 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-02 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-02 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-02 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-02 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-03 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-03 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-03 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-03 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-03 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-03 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-03 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-03 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-03 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-03 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-04 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-04 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-04 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-04 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-04 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-04 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-04 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-04 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-04 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-04 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-05 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-05 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-05 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-05 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-05 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-05 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-05 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-05 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-05 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-05 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-06 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-06 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-06 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-06 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-06 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-06 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-06 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-06 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-06 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-06 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-07 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-07 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-07 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-07 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-07 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-07 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-07 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-07 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-07 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-07 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-08 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-08 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-08 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-08 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-08 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-08 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-08 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-08 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-08 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-08 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-09 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-09 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-09 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-09 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-09 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-09 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-09 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-09 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-09 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-09 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-10 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-10 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-10 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-10 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-10 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-10 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-10 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-10 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-10 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-10 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-11 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-11 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-11 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-11 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-11 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-11 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-11 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-11 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-11 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-11 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-12 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-12 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-12 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-12 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-12 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-12 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-12 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-12 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-12 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-12 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-13 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-13 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-13 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-13 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-13 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-13 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-13 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-13 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-13 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-13 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-14 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-14 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-14 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-14 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-14 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-14 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-14 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-14 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-14 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-14 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-15 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-15 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-15 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-15 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-15 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-15 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-15 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-15 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-15 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-15 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-16 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-16 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-16 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-16 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-16 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-16 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-16 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-16 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-16 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-16 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-17 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-17 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-17 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-17 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-17 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-17 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-17 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-17 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-17 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-17 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-18 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-18 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-18 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-18 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-18 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-18 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-18 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-18 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-18 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-18 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-19 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-19 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-19 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-19 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-19 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-19 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-19 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-19 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-19 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-19 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-20 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-20 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-20 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-20 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-20 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-20 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-20 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-20 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-20 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-20 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-21 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-21 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-21 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-21 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-21 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-21 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-21 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-21 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-21 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-21 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-21 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-22 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-22 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-22 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-22 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-22 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-22 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-22 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-22 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-22 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-22 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-22 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-23 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-23 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-23 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-23 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-23 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-23 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-23 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-23 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-23 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-23 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-23 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-24 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-24 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-24 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-24 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-24 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-24 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-24 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-24 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-24 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-24 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-24 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-25 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-25 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-25 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-25 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-25 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-25 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-25 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-25 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-25 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-25 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-25 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-26 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-26 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-26 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-26 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-26 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-26 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-26 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-26 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-26 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-26 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-26 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-27 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-27 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-27 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-27 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-27 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-27 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-27 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-27 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-27 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-27 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-27 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-28 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-28 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-28 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-28 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-28 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-28 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-28 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-28 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-28 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-28 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-02-28 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-01 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-01 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-01 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-01 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-01 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-01 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-01 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-01 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-01 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-01 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-01 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-01 19:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-02 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-02 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-02 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-02 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-02 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-02 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-02 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-02 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-02 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-02 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-02 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-02 19:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-03 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-03 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-03 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-03 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-03 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-03 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-03 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-03 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-03 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-03 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-03 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-03 19:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-04 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-04 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-04 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-04 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-04 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-04 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-04 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-04 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-04 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-04 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-04 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-04 19:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-05 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-05 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-05 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-05 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-05 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-05 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-05 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-05 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-05 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-05 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-05 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-05 19:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-06 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-06 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-06 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-06 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-06 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-06 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-06 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-06 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-06 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-06 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-06 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-06 19:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-07 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-07 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-07 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-07 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-07 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-07 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-07 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-07 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-07 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-07 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-07 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-07 19:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-08 07:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-08 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-08 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-08 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-08 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
# ...
#  Timestamp('2021-03-14 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-14 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-14 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-14 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-14 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-14 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-14 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-14 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-14 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-14 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-14 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-14 19:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-15 07:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-15 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-15 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-15 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-15 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-15 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-15 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-15 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-15 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-15 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-15 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-15 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-15 19:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-16 07:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-16 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-16 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-16 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-16 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-16 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-16 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-16 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-16 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-16 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-16 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-16 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-16 19:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-17 07:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-17 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-17 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-17 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-17 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-17 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-17 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-17 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-17 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-17 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-17 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-17 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-17 19:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-18 07:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-18 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-18 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-18 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-18 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-18 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-18 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-18 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-18 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-18 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-18 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-18 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-18 19:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-19 07:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-19 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-19 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-19 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-19 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-19 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-19 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-19 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-19 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-19 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-19 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-19 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-19 19:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-20 07:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-20 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-20 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-20 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-20 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-20 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-20 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-20 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-20 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-20 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-20 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-20 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-20 19:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-21 07:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-21 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-21 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-21 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-21 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-21 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-21 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-21 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-21 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-21 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-21 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-21 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-21 19:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-22 07:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-22 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-22 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-22 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-22 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-22 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-22 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-22 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-22 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-22 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-22 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-22 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-22 19:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-23 07:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-23 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-23 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-23 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-23 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-23 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-23 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-23 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-23 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-23 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-23 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-23 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-23 19:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-24 07:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-24 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-24 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-24 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-24 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-24 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-24 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-24 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-24 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-24 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-24 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-24 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-24 19:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-25 07:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-25 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-25 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-25 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-25 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-25 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-25 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-25 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-25 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-25 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-25 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-25 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-25 19:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-26 07:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-26 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-26 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-26 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-26 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-26 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-26 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-26 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-26 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-26 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-26 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-26 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-26 19:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-27 07:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-27 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-27 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-27 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-27 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-27 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-27 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-27 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-27 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-27 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-27 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-27 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-27 19:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-28 07:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-28 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-28 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-28 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-28 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-28 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-28 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-28 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-28 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-28 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-28 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-28 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-28 19:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-29 07:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-29 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-29 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-29 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-29 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-29 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-29 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-29 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-29 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-29 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-29 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-29 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-29 19:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-30 07:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-30 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-30 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-30 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-30 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-30 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-30 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-30 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-30 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-30 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-30 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-30 18:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-30 19:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-31 07:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-31 08:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-31 09:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-31 10:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-31 11:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-31 12:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-31 13:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-31 14:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-31 15:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-31 16:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  Timestamp('2021-03-31 17:00:00-0700', tz='pytz.FixedOffset(-420)'),
#  ...]

# %%
limit_angle = 52 # Max tracker angle is 52 degrees
angledelta = 2 # Sampling every 2 degrees?
backtrack = True
gcr = 0.33
cumulativesky = True # This is important for this example!
trackerdict = radObj.set1axis(metdata = metdata, limit_angle = limit_angle, backtrack = backtrack,
                            gcr = gcr, cumulativesky = cumulativesky)
# Out:
# Saving file EPWs/1axis_-50.0.csv, # points: 617
# Saving file EPWs/1axis_-45.0.csv, # points: 177
# Saving file EPWs/1axis_-40.0.csv, # points: 156
# Saving file EPWs/1axis_-35.0.csv, # points: 96
# Saving file EPWs/1axis_-30.0.csv, # points: 243
# Saving file EPWs/1axis_-25.0.csv, # points: 176
# Saving file EPWs/1axis_-20.0.csv, # points: 99
# Saving file EPWs/1axis_-15.0.csv, # points: 289
# Saving file EPWs/1axis_-10.0.csv, # points: 89
# Saving file EPWs/1axis_-5.0.csv, # points: 172
# Saving file EPWs/1axis_-0.0.csv, # points: 224
# Saving file EPWs/1axis_5.0.csv, # points: 93
# Saving file EPWs/1axis_10.0.csv, # points: 4
# Saving file EPWs/1axis_15.0.csv, # points: 210
# Saving file EPWs/1axis_20.0.csv, # points: 105
# Saving file EPWs/1axis_25.0.csv, # points: 157
# Saving file EPWs/1axis_30.0.csv, # points: 243
# Saving file EPWs/1axis_35.0.csv, # points: 111
# Saving file EPWs/1axis_40.0.csv, # points: 139
# Saving file EPWs/1axis_45.0.csv, # points: 151
# Saving file EPWs/1axis_50.0.csv, # points: 650

# %%
trackerdict = radObj.genCumSky1axis()
# Out:
# message: There were 617 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created skyfile skies/1axis_-50.0.rad
# message: There were 177 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created skyfile skies/1axis_-45.0.rad
# message: There were 156 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created skyfile skies/1axis_-40.0.rad
# message: There were 96 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created skyfile skies/1axis_-35.0.rad
# message: There were 243 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created skyfile skies/1axis_-30.0.rad
# message: There were 175 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created skyfile skies/1axis_-25.0.rad
# message: There were 99 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created skyfile skies/1axis_-20.0.rad
# message: There were 289 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created skyfile skies/1axis_-15.0.rad
# message: There were 89 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created skyfile skies/1axis_-10.0.rad
# message: There were 159 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created skyfile skies/1axis_-5.0.rad
# message: There were 222 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created skyfile skies/1axis_-0.0.rad
# message: There were 93 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created skyfile skies/1axis_5.0.rad
# message: There were 4 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created skyfile skies/1axis_10.0.rad
# message: There were 210 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created skyfile skies/1axis_15.0.rad
# message: There were 103 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created skyfile skies/1axis_20.0.rad
# message: There were 154 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created skyfile skies/1axis_25.0.rad
# message: There were 242 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created skyfile skies/1axis_30.0.rad
# message: There were 111 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created skyfile skies/1axis_35.0.rad
# message: There were 139 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created skyfile skies/1axis_40.0.rad
# message: There were 151 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created skyfile skies/1axis_45.0.rad
# message: There were 650 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created skyfile skies/1axis_50.0.rad

# %%
# Create module
x = 1.232  # meters
y = 2.009  # meters
moduletype = 'test-module'
numpanels = 1
zgap = 0.05
ygap = 0.10
xgap = 0.02

module = radObj.makeModule(name=moduletype, x=x, y=y,xgap=xgap, ygap=ygap, zgap=zgap,
                numpanels=numpanels)

module.addTorquetube(diameter=0.1, material='Metal_Grey', tubetype='round') # New torquetube generation function
print()
print(module)
print()
print(module.torquetube)
# Out:
# Module Name: test-module
# Module test-module updated in module.json
# Pre-existing .rad file objects/test-module.rad will be overwritten
#
# Module test-module updated in module.json
# Pre-existing .rad file objects/test-module.rad will be overwritten
#
#
# {'x': 1.232, 'y': 2.009, 'z': 0.02, 'modulematerial': 'black', 'scenex': 1.252, 'sceney': 2.009, 'scenez': 0.1, 'numpanels': 1, 'bifi': 1, 'text': '! genbox black test-module 1.232 2.009 0.02 | xform -t -0.616 -1.0045 0.1 -a 1 -t 0 2.109 0\r\n! genrev Metal_Grey tube1 t*1.252 0.05 32 | xform -ry 90 -t -0.626 0 0', 'modulefile': 'objects/test-module.rad', 'glass': False, 'offsetfromaxis': 0.1, 'xgap': 0.02, 'ygap': 0.1, 'zgap': 0.05}
#
# {'diameter': 0.1, 'tubetype': 'round', 'material': 'Metal_Grey', 'visible': True}

# %%
# Create the scene
hub_height = 1.651 # height of panel tracker hub
pitch = 6.096 # inter-row spacing
sceneDict = {'gcr': gcr,'hub_height':hub_height, 'nMods': 20, 'nRows': 7}

# %%
# Create the scene
trackerdict = radObj.makeScene1axis(trackerdict = trackerdict, module = module, sceneDict = sceneDict)
# Out:
# Making .rad files for cumulativesky 1-axis workflow
# 21 Radfiles created in /objects/

# %%
# Combine ground, sky, and scene objects
trackerdict = radObj.makeOct1axis(trackerdict = trackerdict)
# Out:
# Making 21 octfiles in root directory.
# Created 1axis_-50.0.oct
# Created 1axis_-45.0.oct
# Created 1axis_-40.0.oct
# Created 1axis_-35.0.oct
# Created 1axis_-30.0.oct
# Created 1axis_-25.0.oct
# Created 1axis_-20.0.oct
# Created 1axis_-15.0.oct
# Created 1axis_-10.0.oct
# Created 1axis_-5.0.oct
# Created 1axis_-0.0.oct
# Created 1axis_5.0.oct
# Created 1axis_10.0.oct
# Created 1axis_15.0.oct
# Created 1axis_20.0.oct
# Created 1axis_25.0.oct
# Created 1axis_30.0.oct
# Created 1axis_35.0.oct
# Created 1axis_40.0.oct
# Created 1axis_45.0.oct
# Created 1axis_50.0.oct

# %%
# Visualize the system
#get_ipython().system('rpict -vf views/front.vp -e .01 1axis_20.0.oct > scene.hdr')
#rpict -vp 10 5 3 -vd 1 -.5 0 scene.oct > scene.jpg

#get_ipython().system('rvu -vf /Users/klepley/Documents/GitHub/InSPIRE/TEMP/FARMS_Arizona/views/front.vp -e 1axis_20.0.oct')

# %%
# Analysis
modWanted = 9
rowWanted = 2
customname = '_Row_2_Module_09' # This is useful if we want to do various analysis.
trackerdict = radObj.analysis1axis(trackerdict, modWanted=9, rowWanted = 2, customname=customname)
# Out:
# Linescan in process: 1axis_-50.0_Row_2_Module_09_Front
# Linescan in process: 1axis_-50.0_Row_2_Module_09_Back
# Saved: results/irr_1axis_-50.0_Row_2_Module_09.csv
# Index: -50.0. Wm2Front: 317817.8851851852. Wm2Back: 26996.4762962963
# Linescan in process: 1axis_-45.0_Row_2_Module_09_Front
# Linescan in process: 1axis_-45.0_Row_2_Module_09_Back
# Saved: results/irr_1axis_-45.0_Row_2_Module_09.csv
# Index: -45.0. Wm2Front: 98488.62037037036. Wm2Back: 10028.43988888889
# Linescan in process: 1axis_-40.0_Row_2_Module_09_Front
# Linescan in process: 1axis_-40.0_Row_2_Module_09_Back
# Saved: results/irr_1axis_-40.0_Row_2_Module_09.csv
# Index: -40.0. Wm2Front: 95365.45888888888. Wm2Back: 9685.130222222222
# Linescan in process: 1axis_-35.0_Row_2_Module_09_Front
# Linescan in process: 1axis_-35.0_Row_2_Module_09_Back
# Saved: results/irr_1axis_-35.0_Row_2_Module_09.csv
# Index: -35.0. Wm2Front: 46570.26. Wm2Back: 5119.0794074074065
# Linescan in process: 1axis_-30.0_Row_2_Module_09_Front
# Linescan in process: 1axis_-30.0_Row_2_Module_09_Back
# Saved: results/irr_1axis_-30.0_Row_2_Module_09.csv
# Index: -30.0. Wm2Front: 131483.38518518518. Wm2Back: 14609.114814814813
# Linescan in process: 1axis_-25.0_Row_2_Module_09_Front
# Linescan in process: 1axis_-25.0_Row_2_Module_09_Back
# Saved: results/irr_1axis_-25.0_Row_2_Module_09.csv
# Index: -25.0. Wm2Front: 84636.62333333335. Wm2Back: 10355.11088888889
# Linescan in process: 1axis_-20.0_Row_2_Module_09_Front
# Linescan in process: 1axis_-20.0_Row_2_Module_09_Back
# Saved: results/irr_1axis_-20.0_Row_2_Module_09.csv
# Index: -20.0. Wm2Front: 34137.112222222226. Wm2Back: 4508.7451481481485
# Linescan in process: 1axis_-15.0_Row_2_Module_09_Front
# Linescan in process: 1axis_-15.0_Row_2_Module_09_Back
# Saved: results/irr_1axis_-15.0_Row_2_Module_09.csv
# Index: -15.0. Wm2Front: 198492.2703703704. Wm2Back: 25989.057037037037
# Linescan in process: 1axis_-10.0_Row_2_Module_09_Front
# Linescan in process: 1axis_-10.0_Row_2_Module_09_Back
# Saved: results/irr_1axis_-10.0_Row_2_Module_09.csv
# Index: -10.0. Wm2Front: 3541.4502222222222. Wm2Back: 348.3579814814815
# Linescan in process: 1axis_-5.0_Row_2_Module_09_Front
# Linescan in process: 1axis_-5.0_Row_2_Module_09_Back
# Saved: results/irr_1axis_-5.0_Row_2_Module_09.csv
# Index: -5.0. Wm2Front: 33031.00925925926. Wm2Back: 4585.397592592593
# Linescan in process: 1axis_-0.0_Row_2_Module_09_Front
# Linescan in process: 1axis_-0.0_Row_2_Module_09_Back
# Saved: results/irr_1axis_-0.0_Row_2_Module_09.csv
# Index: -0.0. Wm2Front: 186921.4111111111. Wm2Back: 24879.91074074074
# Linescan in process: 1axis_5.0_Row_2_Module_09_Front
# Linescan in process: 1axis_5.0_Row_2_Module_09_Back
# Saved: results/irr_1axis_5.0_Row_2_Module_09.csv
# Index: 5.0. Wm2Front: 55772.43. Wm2Back: 7279.10848148148
# Linescan in process: 1axis_10.0_Row_2_Module_09_Front
# Linescan in process: 1axis_10.0_Row_2_Module_09_Back
# Saved: results/irr_1axis_10.0_Row_2_Module_09.csv
# Index: 10.0. Wm2Front: 185.6168037037037. Wm2Back: 27.39850962962963
# Linescan in process: 1axis_15.0_Row_2_Module_09_Front
# Linescan in process: 1axis_15.0_Row_2_Module_09_Back
# Saved: results/irr_1axis_15.0_Row_2_Module_09.csv
# Index: 15.0. Wm2Front: 194477.76296296297. Wm2Back: 23290.506666666664
# Linescan in process: 1axis_20.0_Row_2_Module_09_Front
# Linescan in process: 1axis_20.0_Row_2_Module_09_Back
# Saved: results/irr_1axis_20.0_Row_2_Module_09.csv
# Index: 20.0. Wm2Front: 53540.74185185185. Wm2Back: 7000.6151851851855
# Linescan in process: 1axis_25.0_Row_2_Module_09_Front
# Linescan in process: 1axis_25.0_Row_2_Module_09_Back
# Saved: results/irr_1axis_25.0_Row_2_Module_09.csv
# Index: 25.0. Wm2Front: 81970.30370370371. Wm2Back: 8857.542074074074
# Linescan in process: 1axis_30.0_Row_2_Module_09_Front
# Linescan in process: 1axis_30.0_Row_2_Module_09_Back
# Saved: results/irr_1axis_30.0_Row_2_Module_09.csv
# Index: 30.0. Wm2Front: 177250.30740740744. Wm2Back: 17520.583333333332
# Linescan in process: 1axis_35.0_Row_2_Module_09_Front
# Linescan in process: 1axis_35.0_Row_2_Module_09_Back
# Saved: results/irr_1axis_35.0_Row_2_Module_09.csv
# Index: 35.0. Wm2Front: 80765.9937037037. Wm2Back: 7685.079851851852
# Linescan in process: 1axis_40.0_Row_2_Module_09_Front
# Linescan in process: 1axis_40.0_Row_2_Module_09_Back
# Saved: results/irr_1axis_40.0_Row_2_Module_09.csv
# Index: 40.0. Wm2Front: 121208.86666666664. Wm2Back: 10318.399666666668
# Linescan in process: 1axis_45.0_Row_2_Module_09_Front
# Linescan in process: 1axis_45.0_Row_2_Module_09_Back
# Saved: results/irr_1axis_45.0_Row_2_Module_09.csv
# Index: 45.0. Wm2Front: 135071.77407407408. Wm2Back: 9775.004444444443
# Linescan in process: 1axis_50.0_Row_2_Module_09_Front
# Linescan in process: 1axis_50.0_Row_2_Module_09_Back
# Saved: results/irr_1axis_50.0_Row_2_Module_09.csv
# Index: 50.0. Wm2Front: 490068.44444444444. Wm2Back: 29305.26222222222
# Saving a cumulative-results file in the main simulation folder.This adds up by sensor location the irradiance over all hours or configurations considered.
# Warning: This file saving routine does not clean results, so if your setup has ygaps, or 2+modules or torque tubes, doing a deeper cleaning and working with the individual results files in the results folder is highly suggested.
#
# Saving Cumulative results
# Saved: cumulative_results__Row_2_Module_09.csv
