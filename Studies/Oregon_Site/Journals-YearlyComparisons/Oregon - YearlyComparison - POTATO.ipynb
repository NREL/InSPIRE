# %%
import os
from pathlib import Path

testfolder = os.path.join('TEMP','PotatoY1-Y3')

if not os.path.exists(testfolder):
    os.makedirs(testfolder)
    
print ("Your simulation will be stored in %s" % testfolder)
# Out:
# Your simulation will be stored in TEMP\PotatoY1-Y3

# %%
from bifacial_radiance import *
import numpy as np
import pandas as pd
import datetime
import pvlib

# %%
# This information helps with debugging and getting support :)
import sys, platform
import bifacial_radiance as br
print("Working on a ", platform.system(), platform.release())
print("Python version ", sys.version)
print("Pandas version ", pd.__version__)
print("bifacial_radiance version ", br.__version__)
print("PVLib version ", pvlib.__version__)
# Out:
# Working on a  Windows 10
# Python version  3.11.4 | packaged by Anaconda, Inc. | (main, Jul  5 2023, 13:38:37) [MSC v.1916 64 bit (AMD64)]
# Pandas version  2.1.0
# bifacial_radiance version  0.4.2+236.g6801d3d.dirty
# PVLib version  0.10.4.dev9+ge92ee94

# %%
startdt = datetime.datetime(2001,3,15,0)
enddt = datetime.datetime(2001,6,30,23)

# %%
NREL_API_KEY = None  # <-- please set your NREL API key here
# note you must use "quotes" around your key as it is a string.

if NREL_API_KEY is None:
       NREL_API_KEY = 'DEMO_KEY'  # OK for this demo, but better to get your own key

# %%
#Site 1
#44.57615187732146,-123.23914850912513
lat_1=44.57615187732146
lon_1=-123.23914850912513
lat_2=44.566202648983094
lon_2=-123.30914089141844
#Site 2

# %%
data2019_S1, metdata2019_S1 = pvlib.iotools.get_psm3(
    latitude=lat_1, longitude=lon_1,
    api_key=NREL_API_KEY,
    email='silvana.ovaitt@nrel.gov',  # <-- any email works here fine
    names='2019', map_variables=True, leap_day=False)

data2020_S1, metdata2020_S1 = pvlib.iotools.get_psm3(
    latitude=lat_1, longitude=lon_1,
    api_key=NREL_API_KEY,
    email='silvana.ovaitt@nrel.gov',  # <-- any email works here fine
    names='2020', map_variables=True, leap_day=False)

data2021_S1, metdata2021_S1 = pvlib.iotools.get_psm3(
    latitude=lat_1, longitude=lon_1,
    api_key=NREL_API_KEY,
    email='silvana.ovaitt@nrel.gov',  # <-- any email works here fine
    names='2021', map_variables=True, leap_day=False)

# %%
data2019_S2, metdata2019_S2 = pvlib.iotools.get_psm3(
latitude=lat_2, longitude=lon_2,
api_key=NREL_API_KEY,
email='silvana.ovaitt@nrel.gov',  # <-- any email works here fine
names='2019', map_variables=True, leap_day=False)

data2020_S2, metdata2020_S2 = pvlib.iotools.get_psm3(
latitude=lat_2, longitude=lon_2,
api_key=NREL_API_KEY,
email='silvana.ovaitt@nrel.gov',  # <-- any email works here fine
names='2020', map_variables=True, leap_day=False)

data2021_S2, metdata2021_S2 = pvlib.iotools.get_psm3(
latitude=lat_2, longitude=lon_2,
api_key=NREL_API_KEY,
email='silvana.ovaitt@nrel.gov',  # <-- any email works here fine
names='2021', map_variables=True, leap_day=False)

# %%
lat_site1 = 44.57615187732146   
lon_site2 = -123.23914850912513
clearance_heights = [0.88, 0.9482582, 0.6985] # m
ygaps = [0.02, 0.02, 0.02] # m
cws = [3.3655, 3.3655, 3.9624] # m
rtrs = [6.223, 8.4201, 6.8453] # m
tilt = 25
sazm = 180
albedo = 0.2 # 'grass'
years=[2019,2020,2021]
datasets_S2 = [data2019_S2, data2020_S2, data2021_S2]
metdataset_S2 = [metdata2019_S2, metdata2020_S2, metdata2021_S2]

datasets_S1 = [data2019_S1, data2020_S1, data2021_S1]
metdataset_S1 = [metdata2019_S1, metdata2020_S2, metdata2021_S1]

# Field size. Just going for 'steady state'
nMods = 20
nRows = 7

# %%
startdts = [datetime.datetime(2001,4,1,0),
            datetime.datetime(2001,5,1,0),
            datetime.datetime(2001,6,1,0),
            datetime.datetime(2001,7,1,0),
            datetime.datetime(2001,8,1,0),
            datetime.datetime(2001,9,1,0),
            datetime.datetime(2001,10,1,0),
            datetime.datetime(2001,4,1,0)]

enddts = [datetime.datetime(2001,4,30,23),
          datetime.datetime(2001,5,31,23),
          datetime.datetime(2001,6,30,23),
          datetime.datetime(2001,7,31,23),
          datetime.datetime(2001,8,31,23),
          datetime.datetime(2001,9,30,23),
          datetime.datetime(2001,10,15,0),
          datetime.datetime(2001,10,15,0)]

# %%
demo = RadianceObj('oregon', path=testfolder)
demo.setGround(0.2)
# Out:
# path = TEMP\PotatoY1-Y3
# Making path: images
# Making path: objects
# Making path: results
# Making path: skies
# Making path: EPWs
# Making path: materials
# Loading albedo, 1 value(s), 0.200 avg
# 1 nonzero albedo values.

# %%
simulate = True

if simulate:
    for setup in range(0, 2):
        for year in range(0, 3):
            for mmonth in range(0, len(startdts)):
                y = (cws[setup]-ygaps[setup])/2
                year_str = years[year]
                
                if setup==0:
                    weather = datasets_S1[year]
                    meta = metdataset_S1[year]
                else:
                    weather = datasets_S2[year]
                    meta = metdataset_S2[year]
                    
                module = demo.makeModule(name='module_site'+str(setup+1), x=1, y=y, numpanels=2, 
                                        ygap=ygaps[setup])
                startdt = startdts[mmonth]
                enddt = enddts[mmonth]
                metdata = demo.NSRDBWeatherData(meta, weather,starttime=startdt, endtime=enddt, coerce_year=2001) # read in the EPW weather data from above
                demo.genCumSky(savefile=str(mmonth))
                #demo.gendaylit(4020)  # Use this to simulate only one hour at a time. 

                sceneDict = {'tilt':tilt, 'pitch':rtrs[setup], 'clearance_height':clearance_heights[setup], 
                             'azimuth':sazm, 'nMods':nMods, 'nRows':nRows}  
                scene = demo.makeScene(module=module, sceneDict=sceneDict) 
                octfile = demo.makeOct(demo.getfilelist())  

                analysis = AnalysisObj(octfile, demo.name)
                
                # Module first
                frontscan, backscan = analysis.moduleAnalysis(scene, sensorsx = 1, sensorsy=10)
                analysis.analysis(octfile, 'MODULE_setup_'+(str(setup+1))+'_'+str(year_str)+'_'+str(startdt.month)+'to'+str(enddt.month)+'_', frontscan, backscan)  # compare the back vs front irradiance  

                # Ground
                # spacingbetweensamples = 0.05 # m
                # sensorsy = int(np.floor(rtrs[setup]/spacingbetweensamples)+1)
                sensorsx = 1
                ft2m=0.3556
                bedloc = 0.5*cws[setup]*np.cos(np.radians(tilt))+2.5*ft2m  # Edge + 2.5ft
                bedlocinc = 5*ft2m # 2nd bed is 5 feet from bed 1
                
                groundscan, backscan = analysis.moduleAnalysis(scene, sensorsx = 1, sensorsy=[2, 1])
                groundscan['zstart'] = 0.05  # setting it 5 cm from the ground.
                groundscan['zinc'] = 0   # no tilt necessary. 
                groundscan['ystart'] = bedloc
                groundscan['yinc'] = bedlocinc
                analysis.analysis(octfile, 'GROUND_setup_'+(str(setup+1))+'_'+str(year_str)+'_'+str(startdt.month)+'to'+str(enddt.month)+'_', groundscan, backscan)  # compare the back vs front irradiance  

    filesall = os.listdir('results')

    # Cleanup of Ground 'back' files
    filestoclean = [e for e in filesall if e.endswith('_Back.csv')]
    for cc in range(0, len(filestoclean)):
        filetoclean = filestoclean[cc]
        os.remove(os.path.join('results', filetoclean))
# Out:
# Module Name: module_site1
# Module module_site1 updated in module.json
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 399 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_1_2019_4to4__Row4_Module10_Front
# Linescan in process: MODULE_setup_1_2019_4to4__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_1_2019_4to4__Row4_Module10.csv
# Linescan in process: GROUND_setup_1_2019_4to4__Row4_Module10_Front
# Linescan in process: GROUND_setup_1_2019_4to4__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_1_2019_4to4__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_1_2019_4to4__Row4_Module10_Back.csv
#
# Module Name: module_site1
# Module module_site1 updated in module.json
# Pre-existing .rad file objects\module_site1.rad will be overwritten
#
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 457 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_1_2019_5to5__Row4_Module10_Front
# Linescan in process: MODULE_setup_1_2019_5to5__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_1_2019_5to5__Row4_Module10.csv
# Linescan in process: GROUND_setup_1_2019_5to5__Row4_Module10_Front
# Linescan in process: GROUND_setup_1_2019_5to5__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_1_2019_5to5__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_1_2019_5to5__Row4_Module10_Back.csv
#
# Module Name: module_site1
# Module module_site1 updated in module.json
# Pre-existing .rad file objects\module_site1.rad will be overwritten
#
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 471 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_1_2019_6to6__Row4_Module10_Front
# Linescan in process: MODULE_setup_1_2019_6to6__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_1_2019_6to6__Row4_Module10.csv
# Linescan in process: GROUND_setup_1_2019_6to6__Row4_Module10_Front
# Linescan in process: GROUND_setup_1_2019_6to6__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_1_2019_6to6__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_1_2019_6to6__Row4_Module10_Back.csv
#
# Module Name: module_site1
# Module module_site1 updated in module.json
# Pre-existing .rad file objects\module_site1.rad will be overwritten
#
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 469 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_1_2019_7to7__Row4_Module10_Front
# Linescan in process: MODULE_setup_1_2019_7to7__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_1_2019_7to7__Row4_Module10.csv
# Linescan in process: GROUND_setup_1_2019_7to7__Row4_Module10_Front
# Linescan in process: GROUND_setup_1_2019_7to7__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_1_2019_7to7__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_1_2019_7to7__Row4_Module10_Back.csv
#
# Module Name: module_site1
# Module module_site1 updated in module.json
# Pre-existing .rad file objects\module_site1.rad will be overwritten
#
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 439 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_1_2019_8to8__Row4_Module10_Front
# Linescan in process: MODULE_setup_1_2019_8to8__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_1_2019_8to8__Row4_Module10.csv
# Linescan in process: GROUND_setup_1_2019_8to8__Row4_Module10_Front
# Linescan in process: GROUND_setup_1_2019_8to8__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_1_2019_8to8__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_1_2019_8to8__Row4_Module10_Back.csv
#
# Module Name: module_site1
# Module module_site1 updated in module.json
# Pre-existing .rad file objects\module_site1.rad will be overwritten
#
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 368 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_1_2019_9to9__Row4_Module10_Front
# Linescan in process: MODULE_setup_1_2019_9to9__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_1_2019_9to9__Row4_Module10.csv
# Linescan in process: GROUND_setup_1_2019_9to9__Row4_Module10_Front
# Linescan in process: GROUND_setup_1_2019_9to9__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_1_2019_9to9__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_1_2019_9to9__Row4_Module10_Back.csv
#
# Module Name: module_site1
# Module module_site1 updated in module.json
# Pre-existing .rad file objects\module_site1.rad will be overwritten
#
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 167 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_1_2019_10to10__Row4_Module10_Front
# Linescan in process: MODULE_setup_1_2019_10to10__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_1_2019_10to10__Row4_Module10.csv
# Linescan in process: GROUND_setup_1_2019_10to10__Row4_Module10_Front
# Linescan in process: GROUND_setup_1_2019_10to10__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_1_2019_10to10__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_1_2019_10to10__Row4_Module10_Back.csv
#
# Module Name: module_site1
# Module module_site1 updated in module.json
# Pre-existing .rad file objects\module_site1.rad will be overwritten
#
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 2770 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_1_2019_4to10__Row4_Module10_Front
# Linescan in process: MODULE_setup_1_2019_4to10__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_1_2019_4to10__Row4_Module10.csv
# Linescan in process: GROUND_setup_1_2019_4to10__Row4_Module10_Front
# Linescan in process: GROUND_setup_1_2019_4to10__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_1_2019_4to10__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_1_2019_4to10__Row4_Module10_Back.csv
#
# Module Name: module_site1
# Module module_site1 updated in module.json
# Pre-existing .rad file objects\module_site1.rad will be overwritten
#
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 407 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_1_2020_4to4__Row4_Module10_Front
# Linescan in process: MODULE_setup_1_2020_4to4__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_1_2020_4to4__Row4_Module10.csv
# Linescan in process: GROUND_setup_1_2020_4to4__Row4_Module10_Front
# Linescan in process: GROUND_setup_1_2020_4to4__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_1_2020_4to4__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_1_2020_4to4__Row4_Module10_Back.csv
#
# Module Name: module_site1
# Module module_site1 updated in module.json
# Pre-existing .rad file objects\module_site1.rad will be overwritten
#
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 455 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_1_2020_5to5__Row4_Module10_Front
# Linescan in process: MODULE_setup_1_2020_5to5__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_1_2020_5to5__Row4_Module10.csv
# Linescan in process: GROUND_setup_1_2020_5to5__Row4_Module10_Front
# Linescan in process: GROUND_setup_1_2020_5to5__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_1_2020_5to5__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_1_2020_5to5__Row4_Module10_Back.csv
#
# Module Name: module_site1
# Module module_site1 updated in module.json
# Pre-existing .rad file objects\module_site1.rad will be overwritten
#
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 471 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_1_2020_6to6__Row4_Module10_Front
# Linescan in process: MODULE_setup_1_2020_6to6__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_1_2020_6to6__Row4_Module10.csv
# Linescan in process: GROUND_setup_1_2020_6to6__Row4_Module10_Front
# Linescan in process: GROUND_setup_1_2020_6to6__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_1_2020_6to6__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_1_2020_6to6__Row4_Module10_Back.csv
#
# Module Name: module_site1
# Module module_site1 updated in module.json
# Pre-existing .rad file objects\module_site1.rad will be overwritten
#
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 468 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_1_2020_7to7__Row4_Module10_Front
# Linescan in process: MODULE_setup_1_2020_7to7__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_1_2020_7to7__Row4_Module10.csv
# Linescan in process: GROUND_setup_1_2020_7to7__Row4_Module10_Front
# Linescan in process: GROUND_setup_1_2020_7to7__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_1_2020_7to7__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_1_2020_7to7__Row4_Module10_Back.csv
#
# Module Name: module_site1
# Module module_site1 updated in module.json
# Pre-existing .rad file objects\module_site1.rad will be overwritten
#
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 441 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_1_2020_8to8__Row4_Module10_Front
# Linescan in process: MODULE_setup_1_2020_8to8__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_1_2020_8to8__Row4_Module10.csv
# Linescan in process: GROUND_setup_1_2020_8to8__Row4_Module10_Front
# Linescan in process: GROUND_setup_1_2020_8to8__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_1_2020_8to8__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_1_2020_8to8__Row4_Module10_Back.csv
#
# Module Name: module_site1
# Module module_site1 updated in module.json
# Pre-existing .rad file objects\module_site1.rad will be overwritten
#
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 371 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_1_2020_9to9__Row4_Module10_Front
# Linescan in process: MODULE_setup_1_2020_9to9__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_1_2020_9to9__Row4_Module10.csv
# Linescan in process: GROUND_setup_1_2020_9to9__Row4_Module10_Front
# Linescan in process: GROUND_setup_1_2020_9to9__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_1_2020_9to9__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_1_2020_9to9__Row4_Module10_Back.csv
#
# Module Name: module_site1
# Module module_site1 updated in module.json
# Pre-existing .rad file objects\module_site1.rad will be overwritten
#
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 163 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_1_2020_10to10__Row4_Module10_Front
# Linescan in process: MODULE_setup_1_2020_10to10__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_1_2020_10to10__Row4_Module10.csv
# Linescan in process: GROUND_setup_1_2020_10to10__Row4_Module10_Front
# Linescan in process: GROUND_setup_1_2020_10to10__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_1_2020_10to10__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_1_2020_10to10__Row4_Module10_Back.csv
#
# Module Name: module_site1
# Module module_site1 updated in module.json
# Pre-existing .rad file objects\module_site1.rad will be overwritten
#
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 2776 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_1_2020_4to10__Row4_Module10_Front
# Linescan in process: MODULE_setup_1_2020_4to10__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_1_2020_4to10__Row4_Module10.csv
# Linescan in process: GROUND_setup_1_2020_4to10__Row4_Module10_Front
# Linescan in process: GROUND_setup_1_2020_4to10__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_1_2020_4to10__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_1_2020_4to10__Row4_Module10_Back.csv
#
# Module Name: module_site1
# Module module_site1 updated in module.json
# Pre-existing .rad file objects\module_site1.rad will be overwritten
#
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 405 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_1_2021_4to4__Row4_Module10_Front
# Linescan in process: MODULE_setup_1_2021_4to4__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_1_2021_4to4__Row4_Module10.csv
# Linescan in process: GROUND_setup_1_2021_4to4__Row4_Module10_Front
# Linescan in process: GROUND_setup_1_2021_4to4__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_1_2021_4to4__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_1_2021_4to4__Row4_Module10_Back.csv
#
# Module Name: module_site1
# Module module_site1 updated in module.json
# Pre-existing .rad file objects\module_site1.rad will be overwritten
#
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 460 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_1_2021_5to5__Row4_Module10_Front
# Linescan in process: MODULE_setup_1_2021_5to5__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_1_2021_5to5__Row4_Module10.csv
# Linescan in process: GROUND_setup_1_2021_5to5__Row4_Module10_Front
# Linescan in process: GROUND_setup_1_2021_5to5__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_1_2021_5to5__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_1_2021_5to5__Row4_Module10_Back.csv
#
# Module Name: module_site1
# Module module_site1 updated in module.json
# Pre-existing .rad file objects\module_site1.rad will be overwritten
#
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 470 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_1_2021_6to6__Row4_Module10_Front
# Linescan in process: MODULE_setup_1_2021_6to6__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_1_2021_6to6__Row4_Module10.csv
# Linescan in process: GROUND_setup_1_2021_6to6__Row4_Module10_Front
# Linescan in process: GROUND_setup_1_2021_6to6__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_1_2021_6to6__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_1_2021_6to6__Row4_Module10_Back.csv
#
# Module Name: module_site1
# Module module_site1 updated in module.json
# Pre-existing .rad file objects\module_site1.rad will be overwritten
#
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 469 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_1_2021_7to7__Row4_Module10_Front
# Linescan in process: MODULE_setup_1_2021_7to7__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_1_2021_7to7__Row4_Module10.csv
# Linescan in process: GROUND_setup_1_2021_7to7__Row4_Module10_Front
# Linescan in process: GROUND_setup_1_2021_7to7__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_1_2021_7to7__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_1_2021_7to7__Row4_Module10_Back.csv
#
# Module Name: module_site1
# Module module_site1 updated in module.json
# Pre-existing .rad file objects\module_site1.rad will be overwritten
#
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 438 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_1_2021_8to8__Row4_Module10_Front
# Linescan in process: MODULE_setup_1_2021_8to8__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_1_2021_8to8__Row4_Module10.csv
# Linescan in process: GROUND_setup_1_2021_8to8__Row4_Module10_Front
# Linescan in process: GROUND_setup_1_2021_8to8__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_1_2021_8to8__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_1_2021_8to8__Row4_Module10_Back.csv
#
# Module Name: module_site1
# Module module_site1 updated in module.json
# Pre-existing .rad file objects\module_site1.rad will be overwritten
#
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 368 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_1_2021_9to9__Row4_Module10_Front
# Linescan in process: MODULE_setup_1_2021_9to9__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_1_2021_9to9__Row4_Module10.csv
# Linescan in process: GROUND_setup_1_2021_9to9__Row4_Module10_Front
# Linescan in process: GROUND_setup_1_2021_9to9__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_1_2021_9to9__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_1_2021_9to9__Row4_Module10_Back.csv
#
# Module Name: module_site1
# Module module_site1 updated in module.json
# Pre-existing .rad file objects\module_site1.rad will be overwritten
#
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 165 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_1_2021_10to10__Row4_Module10_Front
# Linescan in process: MODULE_setup_1_2021_10to10__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_1_2021_10to10__Row4_Module10.csv
# Linescan in process: GROUND_setup_1_2021_10to10__Row4_Module10_Front
# Linescan in process: GROUND_setup_1_2021_10to10__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_1_2021_10to10__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_1_2021_10to10__Row4_Module10_Back.csv
#
# Module Name: module_site1
# Module module_site1 updated in module.json
# Pre-existing .rad file objects\module_site1.rad will be overwritten
#
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 2775 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_1_2021_4to10__Row4_Module10_Front
# Linescan in process: MODULE_setup_1_2021_4to10__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_1_2021_4to10__Row4_Module10.csv
# Linescan in process: GROUND_setup_1_2021_4to10__Row4_Module10_Front
# Linescan in process: GROUND_setup_1_2021_4to10__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_1_2021_4to10__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_1_2021_4to10__Row4_Module10_Back.csv
#
# Module Name: module_site2
# Module module_site2 updated in module.json
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 401 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_2_2019_4to4__Row4_Module10_Front
# Linescan in process: MODULE_setup_2_2019_4to4__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_2_2019_4to4__Row4_Module10.csv
# Linescan in process: GROUND_setup_2_2019_4to4__Row4_Module10_Front
# Linescan in process: GROUND_setup_2_2019_4to4__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_2_2019_4to4__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_2_2019_4to4__Row4_Module10_Back.csv
#
# Module Name: module_site2
# Module module_site2 updated in module.json
# Pre-existing .rad file objects\module_site2.rad will be overwritten
#
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 453 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_2_2019_5to5__Row4_Module10_Front
# Linescan in process: MODULE_setup_2_2019_5to5__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_2_2019_5to5__Row4_Module10.csv
# Linescan in process: GROUND_setup_2_2019_5to5__Row4_Module10_Front
# Linescan in process: GROUND_setup_2_2019_5to5__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_2_2019_5to5__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_2_2019_5to5__Row4_Module10_Back.csv
#
# Module Name: module_site2
# Module module_site2 updated in module.json
# Pre-existing .rad file objects\module_site2.rad will be overwritten
#
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 472 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_2_2019_6to6__Row4_Module10_Front
# Linescan in process: MODULE_setup_2_2019_6to6__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_2_2019_6to6__Row4_Module10.csv
# Linescan in process: GROUND_setup_2_2019_6to6__Row4_Module10_Front
# Linescan in process: GROUND_setup_2_2019_6to6__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_2_2019_6to6__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_2_2019_6to6__Row4_Module10_Back.csv
#
# Module Name: module_site2
# Module module_site2 updated in module.json
# Pre-existing .rad file objects\module_site2.rad will be overwritten
#
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 467 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_2_2019_7to7__Row4_Module10_Front
# Linescan in process: MODULE_setup_2_2019_7to7__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_2_2019_7to7__Row4_Module10.csv
# Linescan in process: GROUND_setup_2_2019_7to7__Row4_Module10_Front
# Linescan in process: GROUND_setup_2_2019_7to7__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_2_2019_7to7__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_2_2019_7to7__Row4_Module10_Back.csv
#
# Module Name: module_site2
# Module module_site2 updated in module.json
# Pre-existing .rad file objects\module_site2.rad will be overwritten
#
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 439 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_2_2019_8to8__Row4_Module10_Front
# Linescan in process: MODULE_setup_2_2019_8to8__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_2_2019_8to8__Row4_Module10.csv
# Linescan in process: GROUND_setup_2_2019_8to8__Row4_Module10_Front
# Linescan in process: GROUND_setup_2_2019_8to8__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_2_2019_8to8__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_2_2019_8to8__Row4_Module10_Back.csv
#
# Module Name: module_site2
# Module module_site2 updated in module.json
# Pre-existing .rad file objects\module_site2.rad will be overwritten
#
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 372 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_2_2019_9to9__Row4_Module10_Front
# Linescan in process: MODULE_setup_2_2019_9to9__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_2_2019_9to9__Row4_Module10.csv
# Linescan in process: GROUND_setup_2_2019_9to9__Row4_Module10_Front
# Linescan in process: GROUND_setup_2_2019_9to9__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_2_2019_9to9__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_2_2019_9to9__Row4_Module10_Back.csv
#
# Module Name: module_site2
# Module module_site2 updated in module.json
# Pre-existing .rad file objects\module_site2.rad will be overwritten
#
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 166 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_2_2019_10to10__Row4_Module10_Front
# Linescan in process: MODULE_setup_2_2019_10to10__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_2_2019_10to10__Row4_Module10.csv
# Linescan in process: GROUND_setup_2_2019_10to10__Row4_Module10_Front
# Linescan in process: GROUND_setup_2_2019_10to10__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_2_2019_10to10__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_2_2019_10to10__Row4_Module10_Back.csv
#
# Module Name: module_site2
# Module module_site2 updated in module.json
# Pre-existing .rad file objects\module_site2.rad will be overwritten
#
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 2770 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_2_2019_4to10__Row4_Module10_Front
# Linescan in process: MODULE_setup_2_2019_4to10__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_2_2019_4to10__Row4_Module10.csv
# Linescan in process: GROUND_setup_2_2019_4to10__Row4_Module10_Front
# Linescan in process: GROUND_setup_2_2019_4to10__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_2_2019_4to10__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_2_2019_4to10__Row4_Module10_Back.csv
#
# Module Name: module_site2
# Module module_site2 updated in module.json
# Pre-existing .rad file objects\module_site2.rad will be overwritten
#
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 405 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_2_2020_4to4__Row4_Module10_Front
# Linescan in process: MODULE_setup_2_2020_4to4__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_2_2020_4to4__Row4_Module10.csv
# Linescan in process: GROUND_setup_2_2020_4to4__Row4_Module10_Front
# Linescan in process: GROUND_setup_2_2020_4to4__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_2_2020_4to4__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_2_2020_4to4__Row4_Module10_Back.csv
#
# Module Name: module_site2
# Module module_site2 updated in module.json
# Pre-existing .rad file objects\module_site2.rad will be overwritten
#
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 454 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_2_2020_5to5__Row4_Module10_Front
# Linescan in process: MODULE_setup_2_2020_5to5__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_2_2020_5to5__Row4_Module10.csv
# Linescan in process: GROUND_setup_2_2020_5to5__Row4_Module10_Front
# Linescan in process: GROUND_setup_2_2020_5to5__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_2_2020_5to5__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_2_2020_5to5__Row4_Module10_Back.csv
#
# Module Name: module_site2
# Module module_site2 updated in module.json
# Pre-existing .rad file objects\module_site2.rad will be overwritten
#
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 471 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_2_2020_6to6__Row4_Module10_Front
# Linescan in process: MODULE_setup_2_2020_6to6__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_2_2020_6to6__Row4_Module10.csv
# Linescan in process: GROUND_setup_2_2020_6to6__Row4_Module10_Front
# Linescan in process: GROUND_setup_2_2020_6to6__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_2_2020_6to6__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_2_2020_6to6__Row4_Module10_Back.csv
#
# Module Name: module_site2
# Module module_site2 updated in module.json
# Pre-existing .rad file objects\module_site2.rad will be overwritten
#
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 467 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_2_2020_7to7__Row4_Module10_Front
# Linescan in process: MODULE_setup_2_2020_7to7__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_2_2020_7to7__Row4_Module10.csv
# Linescan in process: GROUND_setup_2_2020_7to7__Row4_Module10_Front
# Linescan in process: GROUND_setup_2_2020_7to7__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_2_2020_7to7__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_2_2020_7to7__Row4_Module10_Back.csv
#
# Module Name: module_site2
# Module module_site2 updated in module.json
# Pre-existing .rad file objects\module_site2.rad will be overwritten
#
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 442 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_2_2020_8to8__Row4_Module10_Front
# Linescan in process: MODULE_setup_2_2020_8to8__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_2_2020_8to8__Row4_Module10.csv
# Linescan in process: GROUND_setup_2_2020_8to8__Row4_Module10_Front
# Linescan in process: GROUND_setup_2_2020_8to8__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_2_2020_8to8__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_2_2020_8to8__Row4_Module10_Back.csv
#
# Module Name: module_site2
# Module module_site2 updated in module.json
# Pre-existing .rad file objects\module_site2.rad will be overwritten
#
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 372 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_2_2020_9to9__Row4_Module10_Front
# Linescan in process: MODULE_setup_2_2020_9to9__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_2_2020_9to9__Row4_Module10.csv
# Linescan in process: GROUND_setup_2_2020_9to9__Row4_Module10_Front
# Linescan in process: GROUND_setup_2_2020_9to9__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_2_2020_9to9__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_2_2020_9to9__Row4_Module10_Back.csv
#
# Module Name: module_site2
# Module module_site2 updated in module.json
# Pre-existing .rad file objects\module_site2.rad will be overwritten
#
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 163 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_2_2020_10to10__Row4_Module10_Front
# Linescan in process: MODULE_setup_2_2020_10to10__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_2_2020_10to10__Row4_Module10.csv
# Linescan in process: GROUND_setup_2_2020_10to10__Row4_Module10_Front
# Linescan in process: GROUND_setup_2_2020_10to10__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_2_2020_10to10__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_2_2020_10to10__Row4_Module10_Back.csv
#
# Module Name: module_site2
# Module module_site2 updated in module.json
# Pre-existing .rad file objects\module_site2.rad will be overwritten
#
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 2774 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_2_2020_4to10__Row4_Module10_Front
# Linescan in process: MODULE_setup_2_2020_4to10__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_2_2020_4to10__Row4_Module10.csv
# Linescan in process: GROUND_setup_2_2020_4to10__Row4_Module10_Front
# Linescan in process: GROUND_setup_2_2020_4to10__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_2_2020_4to10__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_2_2020_4to10__Row4_Module10_Back.csv
#
# Module Name: module_site2
# Module module_site2 updated in module.json
# Pre-existing .rad file objects\module_site2.rad will be overwritten
#
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 405 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_2_2021_4to4__Row4_Module10_Front
# Linescan in process: MODULE_setup_2_2021_4to4__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_2_2021_4to4__Row4_Module10.csv
# Linescan in process: GROUND_setup_2_2021_4to4__Row4_Module10_Front
# Linescan in process: GROUND_setup_2_2021_4to4__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_2_2021_4to4__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_2_2021_4to4__Row4_Module10_Back.csv
#
# Module Name: module_site2
# Module module_site2 updated in module.json
# Pre-existing .rad file objects\module_site2.rad will be overwritten
#
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 456 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_2_2021_5to5__Row4_Module10_Front
# Linescan in process: MODULE_setup_2_2021_5to5__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_2_2021_5to5__Row4_Module10.csv
# Linescan in process: GROUND_setup_2_2021_5to5__Row4_Module10_Front
# Linescan in process: GROUND_setup_2_2021_5to5__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_2_2021_5to5__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_2_2021_5to5__Row4_Module10_Back.csv
#
# Module Name: module_site2
# Module module_site2 updated in module.json
# Pre-existing .rad file objects\module_site2.rad will be overwritten
#
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 473 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_2_2021_6to6__Row4_Module10_Front
# Linescan in process: MODULE_setup_2_2021_6to6__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_2_2021_6to6__Row4_Module10.csv
# Linescan in process: GROUND_setup_2_2021_6to6__Row4_Module10_Front
# Linescan in process: GROUND_setup_2_2021_6to6__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_2_2021_6to6__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_2_2021_6to6__Row4_Module10_Back.csv
#
# Module Name: module_site2
# Module module_site2 updated in module.json
# Pre-existing .rad file objects\module_site2.rad will be overwritten
#
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 466 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_2_2021_7to7__Row4_Module10_Front
# Linescan in process: MODULE_setup_2_2021_7to7__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_2_2021_7to7__Row4_Module10.csv
# Linescan in process: GROUND_setup_2_2021_7to7__Row4_Module10_Front
# Linescan in process: GROUND_setup_2_2021_7to7__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_2_2021_7to7__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_2_2021_7to7__Row4_Module10_Back.csv
#
# Module Name: module_site2
# Module module_site2 updated in module.json
# Pre-existing .rad file objects\module_site2.rad will be overwritten
#
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 441 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_2_2021_8to8__Row4_Module10_Front
# Linescan in process: MODULE_setup_2_2021_8to8__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_2_2021_8to8__Row4_Module10.csv
# Linescan in process: GROUND_setup_2_2021_8to8__Row4_Module10_Front
# Linescan in process: GROUND_setup_2_2021_8to8__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_2_2021_8to8__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_2_2021_8to8__Row4_Module10_Back.csv
#
# Module Name: module_site2
# Module module_site2 updated in module.json
# Pre-existing .rad file objects\module_site2.rad will be overwritten
#
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 373 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_2_2021_9to9__Row4_Module10_Front
# Linescan in process: MODULE_setup_2_2021_9to9__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_2_2021_9to9__Row4_Module10.csv
# Linescan in process: GROUND_setup_2_2021_9to9__Row4_Module10_Front
# Linescan in process: GROUND_setup_2_2021_9to9__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_2_2021_9to9__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_2_2021_9to9__Row4_Module10_Back.csv
#
# Module Name: module_site2
# Module module_site2 updated in module.json
# Pre-existing .rad file objects\module_site2.rad will be overwritten
#
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 160 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_2_2021_10to10__Row4_Module10_Front
# Linescan in process: MODULE_setup_2_2021_10to10__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_2_2021_10to10__Row4_Module10.csv
# Linescan in process: GROUND_setup_2_2021_10to10__Row4_Module10_Front
# Linescan in process: GROUND_setup_2_2021_10to10__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_2_2021_10to10__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_2_2021_10to10__Row4_Module10_Back.csv
#
# Module Name: module_site2
# Module module_site2 updated in module.json
# Pre-existing .rad file objects\module_site2.rad will be overwritten
#
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2001
# Filtering dates
# Saving file EPWs\metdata_temp.csv, # points: 8760
# Calculating Sun position for center labeled data, at exact timestamp in input Weather File
# Loaded  EPWs\metdata_temp.csv
# message: There were 2774 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created oregon.oct
# Linescan in process: MODULE_setup_2_2021_4to10__Row4_Module10_Front
# Linescan in process: MODULE_setup_2_2021_4to10__Row4_Module10_Back
# Saved: results\irr_MODULE_setup_2_2021_4to10__Row4_Module10.csv
# Linescan in process: GROUND_setup_2_2021_4to10__Row4_Module10_Front
# Linescan in process: GROUND_setup_2_2021_4to10__Row4_Module10_Back
# Saved: results\irr_GROUND_setup_2_2021_4to10__Row4_Module10_Front.csv
# Saved: results\irr_GROUND_setup_2_2021_4to10__Row4_Module10_Back.csv
